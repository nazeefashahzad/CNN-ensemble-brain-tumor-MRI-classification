# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pathlib

# %%
data = pathlib.Path('/content/drive/My Drive/brain_tumor_two')

# %%
# !pip install mplcyberpunk
# Out:
# Collecting mplcyberpunk
#   Downloading mplcyberpunk-0.7.1-py3-none-any.whl.metadata (546 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplcyberpunk) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplcyberpunk) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplcyberpunk) (1.16.0)
# Downloading mplcyberpunk-0.7.1-py3-none-any.whl (6.4 kB)
# Installing collected packages: mplcyberpunk
# Successfully installed mplcyberpunk-0.7.1

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use("cyberpunk")
import cv2
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Dense, Flatten, Dropout, Input, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
from tqdm import tqdm # for adding progress bars to loops
from tensorflow.keras.regularizers import l2

# #from bm3d import bm3d, BM3DProfile
from warnings import filterwarnings # for managing warning messages
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# Data Preparation
X_train = [] # Intializes lists
y_train = []
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']
image_size =340
for i in labels:
    folderPath = os.path.join('/content/drive/My Drive/brain_tumor_two/Training_two',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('/content/drive/My Drive/brain_tumor_two/Testing_two',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 1331/1331 [00:45<00:00, 29.15it/s]
# 100%|██████████| 1595/1595 [00:50<00:00, 31.51it/s]
# 100%|██████████| 1339/1339 [00:31<00:00, 43.16it/s]
# 100%|██████████| 1457/1457 [00:40<00:00, 36.06it/s]
# 100%|██████████| 300/300 [00:06<00:00, 46.64it/s]
# 100%|██████████| 405/405 [00:08<00:00, 50.03it/s]
# 100%|██████████| 306/306 [00:06<00:00, 44.55it/s]
# 100%|██████████| 300/300 [00:07<00:00, 42.14it/s]

# %%
# Data visualization
# Calculate the bar plot for each label
label_counts = {label: np.sum(y_train == label) for label in labels}

# Plot the bar plot and sample images in one chart
plt.figure(figsize=(8, 6),facecolor='Green')
colors = ['red', 'green', 'blue', 'yellow']

# Plot the histogram
plt.subplot(2, 1, 1,facecolor='black')
bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
mplcyberpunk.add_bar_gradient(bars=bars)
# plt.xlabel('Labels')
plt.ylabel('Count')
plt.title('Distribution of Labels')

# Plot sample images from each label
k = 0
for i in labels:
    j = 0
    while True:
        if y_train[j] == i:
            plt.subplot(2, 4, k + 5)
            plt.imshow(X_train[j])
            plt.axis('off')
            k += 1
            break
        j += 1

plt.tight_layout()
plt.show()

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.15,random_state=101)

# %%
print(X_train.max(), X_train.min())
print(X_test.max(), X_test.min())
X_train = X_train/255
X_test = X_test/255
print(X_train.max(), X_train.min())
print(X_test.max(), X_test.min())
# Out:
# 255 0
# 255 0
# 1.0 0.0
# 1.0 0.0

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Flatten, Average, Dropout, GlobalAveragePooling2D, BatchNormalization, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG19,VGG16,ResNet152,MobileNet,InceptionV3,Xception,EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt


# Define the input layer
input_layer = Input(shape=(340, 340, 3))

# Custom CNN model
#l2_values = [0.0001, 0.001, 0.01, 0.1]
l2_values=[0.01]
results = {}

for l2_value in l2_values:
    print(f'Training with L2 regularization: {l2_value}')
cnn_model = Sequential([
    # First convolutional block
    Conv2D(32, (9, 9), padding='same', kernel_regularizer=l2(l2_value), input_shape=(340, 340, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    # Second convolutional block
    Conv2D(64, (9, 9), padding='same', kernel_regularizer=l2(l2_value)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    # Third convolutional block
    Conv2D(128, (9, 9), padding='same', kernel_regularizer=l2(l2_value)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    # Fourth convolutional block
    Conv2D(256, (9, 9), padding='same', kernel_regularizer=l2(l2_value)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    Conv2D(512, (9, 9), padding='same', kernel_regularizer=l2(l2_value)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    Conv2D(1024, (9, 9), padding='same', kernel_regularizer=l2(l2_value)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    Conv2D(2048, (9, 9), padding='same', kernel_regularizer=l2(l2_value)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    GlobalAveragePooling2D(),

    Flatten()
])(input_layer)

# MobileNet model, without the top layer
mobilenet_base = MobileNet(weights='imagenet', include_top=False, input_shape=(340, 340, 3))
for layer in mobilenet_base.layers:
    layer.trainable = False  # Freeze VGG16 layers
mobilenet_output = GlobalAveragePooling2D()(mobilenet_base.output)

# Add dense layers to both models
cnn_dense = Dense(2048, activation='relu')(cnn_model)
cnn_dense = Dropout(0.5)(cnn_dense)

mobilenet_dense = Dense(2048, activation='relu')(mobilenet_output)
mobilenet_dense = Dropout(0.5)(mobilenet_dense)

# Ensemble layer - Average the outputs
ensemble_output = Average()([cnn_dense, mobilenet_dense])

# Final output layer
output_layer = Dense(4, activation='softmax')(ensemble_output)  # Assuming 4 classes

# Create the ensemble model
ensemble_model = Model(inputs=[input_layer, mobilenet_base.input], outputs=output_layer)

# Compile the model
ensemble_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
ensemble_model.summary()

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
tensorboard = TensorBoard(log_dir='logs')
checkpoint = ModelCheckpoint("ensemble_model_MobileNet.keras", monitor="val_accuracy", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_lr=1e-7, verbose=1)

# Train the model
class_weights = {0: 2.0, 1: 2.0, 2: 2.0, 3: 2.0}  # Adjust based on class imbalance if necessary

history = ensemble_model.fit(

    [X_train, X_train],  # Duplicate X_train for both input branches
    y_train,
    validation_split=0.15,
    epochs=50,
    verbose=1,
    batch_size=32,
    class_weight=class_weights,
    callbacks=[early_stopping, tensorboard, checkpoint, reduce_lr]
)



# Evaluate the model
scores = ensemble_model.evaluate([X_test, X_test], y_test)  # Duplicate X_test for both input branches
print("Test Accuracy:", scores[1])
# Out:
# Training with L2 regularization: 0.01
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# <ipython-input-12-ab375e0a527f>:67: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   mobilenet_base = MobileNet(weights='imagenet', include_top=False, input_shape=(340, 340, 3))
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 340, 340, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1 (Conv2D)            │ (None, 170, 170, 32)   │            864 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 170, 170, 32)   │            128 │ conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (ReLU)         │ (None, 170, 170, 32)   │              0 │ conv1_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_1                 │ (None, 170, 170, 32)   │            288 │ conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_1_bn              │ (None, 170, 170, 32)   │            128 │ conv_dw_1[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_1_relu (ReLU)     │ (None, 170, 170, 32)   │              0 │ conv_dw_1_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_1 (Conv2D)        │ (None, 170, 170, 64)   │          2,048 │ conv_dw_1_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_1_bn              │ (None, 170, 170, 64)   │            256 │ conv_pw_1[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_1_relu (ReLU)     │ (None, 170, 170, 64)   │              0 │ conv_pw_1_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pad_2                │ (None, 171, 171, 64)   │              0 │ conv_pw_1_relu[0][0]   │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_2                 │ (None, 85, 85, 64)     │            576 │ conv_pad_2[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_2_bn              │ (None, 85, 85, 64)     │            256 │ conv_dw_2[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_2_relu (ReLU)     │ (None, 85, 85, 64)     │              0 │ conv_dw_2_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_2 (Conv2D)        │ (None, 85, 85, 128)    │          8,192 │ conv_dw_2_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_2_bn              │ (None, 85, 85, 128)    │            512 │ conv_pw_2[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_2_relu (ReLU)     │ (None, 85, 85, 128)    │              0 │ conv_pw_2_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_3                 │ (None, 85, 85, 128)    │          1,152 │ conv_pw_2_relu[0][0]   │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_3_bn              │ (None, 85, 85, 128)    │            512 │ conv_dw_3[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_3_relu (ReLU)     │ (None, 85, 85, 128)    │              0 │ conv_dw_3_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_3 (Conv2D)        │ (None, 85, 85, 128)    │         16,384 │ conv_dw_3_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_3_bn              │ (None, 85, 85, 128)    │            512 │ conv_pw_3[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_3_relu (ReLU)     │ (None, 85, 85, 128)    │              0 │ conv_pw_3_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pad_4                │ (None, 86, 86, 128)    │              0 │ conv_pw_3_relu[0][0]   │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_4                 │ (None, 42, 42, 128)    │          1,152 │ conv_pad_4[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_4_bn              │ (None, 42, 42, 128)    │            512 │ conv_dw_4[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_4_relu (ReLU)     │ (None, 42, 42, 128)    │              0 │ conv_dw_4_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_4 (Conv2D)        │ (None, 42, 42, 256)    │         32,768 │ conv_dw_4_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_4_bn              │ (None, 42, 42, 256)    │          1,024 │ conv_pw_4[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_4_relu (ReLU)     │ (None, 42, 42, 256)    │              0 │ conv_pw_4_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_5                 │ (None, 42, 42, 256)    │          2,304 │ conv_pw_4_relu[0][0]   │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_5_bn              │ (None, 42, 42, 256)    │          1,024 │ conv_dw_5[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_5_relu (ReLU)     │ (None, 42, 42, 256)    │              0 │ conv_dw_5_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_5 (Conv2D)        │ (None, 42, 42, 256)    │         65,536 │ conv_dw_5_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_5_bn              │ (None, 42, 42, 256)    │          1,024 │ conv_pw_5[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_5_relu (ReLU)     │ (None, 42, 42, 256)    │              0 │ conv_pw_5_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pad_6                │ (None, 43, 43, 256)    │              0 │ conv_pw_5_relu[0][0]   │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_6                 │ (None, 21, 21, 256)    │          2,304 │ conv_pad_6[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_6_bn              │ (None, 21, 21, 256)    │          1,024 │ conv_dw_6[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_6_relu (ReLU)     │ (None, 21, 21, 256)    │              0 │ conv_dw_6_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_6 (Conv2D)        │ (None, 21, 21, 512)    │        131,072 │ conv_dw_6_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_6_bn              │ (None, 21, 21, 512)    │          2,048 │ conv_pw_6[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_6_relu (ReLU)     │ (None, 21, 21, 512)    │              0 │ conv_pw_6_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_7                 │ (None, 21, 21, 512)    │          4,608 │ conv_pw_6_relu[0][0]   │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_7_bn              │ (None, 21, 21, 512)    │          2,048 │ conv_dw_7[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_7_relu (ReLU)     │ (None, 21, 21, 512)    │              0 │ conv_dw_7_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_7 (Conv2D)        │ (None, 21, 21, 512)    │        262,144 │ conv_dw_7_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_7_bn              │ (None, 21, 21, 512)    │          2,048 │ conv_pw_7[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_7_relu (ReLU)     │ (None, 21, 21, 512)    │              0 │ conv_pw_7_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_8                 │ (None, 21, 21, 512)    │          4,608 │ conv_pw_7_relu[0][0]   │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_8_bn              │ (None, 21, 21, 512)    │          2,048 │ conv_dw_8[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_8_relu (ReLU)     │ (None, 21, 21, 512)    │              0 │ conv_dw_8_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_8 (Conv2D)        │ (None, 21, 21, 512)    │        262,144 │ conv_dw_8_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_8_bn              │ (None, 21, 21, 512)    │          2,048 │ conv_pw_8[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_8_relu (ReLU)     │ (None, 21, 21, 512)    │              0 │ conv_pw_8_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_9                 │ (None, 21, 21, 512)    │          4,608 │ conv_pw_8_relu[0][0]   │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_9_bn              │ (None, 21, 21, 512)    │          2,048 │ conv_dw_9[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_9_relu (ReLU)     │ (None, 21, 21, 512)    │              0 │ conv_dw_9_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_9 (Conv2D)        │ (None, 21, 21, 512)    │        262,144 │ conv_dw_9_relu[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_9_bn              │ (None, 21, 21, 512)    │          2,048 │ conv_pw_9[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_9_relu (ReLU)     │ (None, 21, 21, 512)    │              0 │ conv_pw_9_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_10                │ (None, 21, 21, 512)    │          4,608 │ conv_pw_9_relu[0][0]   │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_10_bn             │ (None, 21, 21, 512)    │          2,048 │ conv_dw_10[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_10_relu (ReLU)    │ (None, 21, 21, 512)    │              0 │ conv_dw_10_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_10 (Conv2D)       │ (None, 21, 21, 512)    │        262,144 │ conv_dw_10_relu[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_10_bn             │ (None, 21, 21, 512)    │          2,048 │ conv_pw_10[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_10_relu (ReLU)    │ (None, 21, 21, 512)    │              0 │ conv_pw_10_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_11                │ (None, 21, 21, 512)    │          4,608 │ conv_pw_10_relu[0][0]  │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_11_bn             │ (None, 21, 21, 512)    │          2,048 │ conv_dw_11[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_11_relu (ReLU)    │ (None, 21, 21, 512)    │              0 │ conv_dw_11_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_11 (Conv2D)       │ (None, 21, 21, 512)    │        262,144 │ conv_dw_11_relu[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_11_bn             │ (None, 21, 21, 512)    │          2,048 │ conv_pw_11[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_11_relu (ReLU)    │ (None, 21, 21, 512)    │              0 │ conv_pw_11_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pad_12               │ (None, 22, 22, 512)    │              0 │ conv_pw_11_relu[0][0]  │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_12                │ (None, 10, 10, 512)    │          4,608 │ conv_pad_12[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_12_bn             │ (None, 10, 10, 512)    │          2,048 │ conv_dw_12[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_12_relu (ReLU)    │ (None, 10, 10, 512)    │              0 │ conv_dw_12_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_12 (Conv2D)       │ (None, 10, 10, 1024)   │        524,288 │ conv_dw_12_relu[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_12_bn             │ (None, 10, 10, 1024)   │          4,096 │ conv_pw_12[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_12_relu (ReLU)    │ (None, 10, 10, 1024)   │              0 │ conv_pw_12_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_13                │ (None, 10, 10, 1024)   │          9,216 │ conv_pw_12_relu[0][0]  │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_13_bn             │ (None, 10, 10, 1024)   │          4,096 │ conv_dw_13[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_dw_13_relu (ReLU)    │ (None, 10, 10, 1024)   │              0 │ conv_dw_13_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_13 (Conv2D)       │ (None, 10, 10, 1024)   │      1,048,576 │ conv_dw_13_relu[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_13_bn             │ (None, 10, 10, 1024)   │          4,096 │ conv_pw_13[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer (InputLayer)  │ (None, 340, 340, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_pw_13_relu (ReLU)    │ (None, 10, 10, 1024)   │              0 │ conv_pw_13_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential (Sequential)   │ (None, 2048)           │    226,465,216 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1024)           │              0 │ conv_pw_13_relu[0][0]  │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 2048)           │      4,196,352 │ sequential[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 2048)           │      2,099,200 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 2048)           │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 2048)           │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average (Average)         │ (None, 2048)           │              0 │ dropout[0][0],         │
# │                           │                        │                │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 4)              │          8,196 │ average[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 235,997,828 (900.26 MB)
#  Trainable params: 232,760,836 (887.91 MB)
#  Non-trainable params: 3,236,992 (12.35 MB)
# Epoch 1/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.6873 - loss: 24.2502
# Epoch 1: val_accuracy improved from -inf to 0.93534, saving model to ensemble_model_MobileNet.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 151s 631ms/step - accuracy: 0.6880 - loss: 24.1740 - val_accuracy: 0.9353 - val_loss: 1.3528 - learning_rate: 0.0010
# Epoch 2/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8807 - loss: 1.6075
# Epoch 2: val_accuracy did not improve from 0.93534
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.8807 - loss: 1.6066 - val_accuracy: 0.9353 - val_loss: 0.6905 - learning_rate: 0.0010
# Epoch 3/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9156 - loss: 0.9406
# Epoch 3: val_accuracy did not improve from 0.93534
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9156 - loss: 0.9408 - val_accuracy: 0.7938 - val_loss: 2.8723 - learning_rate: 0.0010
# Epoch 4/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9310 - loss: 1.0330
# Epoch 4: val_accuracy improved from 0.93534 to 0.94760, saving model to ensemble_model_MobileNet.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 38s 240ms/step - accuracy: 0.9310 - loss: 1.0321 - val_accuracy: 0.9476 - val_loss: 0.4984 - learning_rate: 0.0010
# Epoch 5/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9437 - loss: 0.5990
# Epoch 5: val_accuracy improved from 0.94760 to 0.95652, saving model to ensemble_model_MobileNet.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 38s 237ms/step - accuracy: 0.9437 - loss: 0.5995 - val_accuracy: 0.9565 - val_loss: 0.5546 - learning_rate: 0.0010
# Epoch 6/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9521 - loss: 0.6053
# Epoch 6: val_accuracy did not improve from 0.95652
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 140ms/step - accuracy: 0.9521 - loss: 0.6053 - val_accuracy: 0.9532 - val_loss: 0.3593 - learning_rate: 0.0010
# Epoch 7/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9445 - loss: 0.4942
# Epoch 7: val_accuracy did not improve from 0.95652
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9445 - loss: 0.4943 - val_accuracy: 0.9543 - val_loss: 0.8432 - learning_rate: 0.0010
# Epoch 8/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9553 - loss: 0.5148
# Epoch 8: val_accuracy improved from 0.95652 to 0.96544, saving model to ensemble_model_MobileNet.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 38s 237ms/step - accuracy: 0.9553 - loss: 0.5145 - val_accuracy: 0.9654 - val_loss: 0.3654 - learning_rate: 0.0010
# Epoch 9/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9697 - loss: 0.2919
# Epoch 9: val_accuracy did not improve from 0.96544
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9697 - loss: 0.2916 - val_accuracy: 0.9643 - val_loss: 0.1475 - learning_rate: 1.0000e-04
# Epoch 10/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9784 - loss: 0.1810
# Epoch 10: val_accuracy did not improve from 0.96544
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9784 - loss: 0.1809 - val_accuracy: 0.9632 - val_loss: 0.1432 - learning_rate: 1.0000e-04
# Epoch 11/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9830 - loss: 0.1567
# Epoch 11: val_accuracy did not improve from 0.96544
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9830 - loss: 0.1567 - val_accuracy: 0.9654 - val_loss: 0.1390 - learning_rate: 1.0000e-04
# Epoch 12/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9804 - loss: 0.1641
# Epoch 12: val_accuracy improved from 0.96544 to 0.96656, saving model to ensemble_model_MobileNet.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 40s 255ms/step - accuracy: 0.9804 - loss: 0.1641 - val_accuracy: 0.9666 - val_loss: 0.1436 - learning_rate: 1.0000e-04
# Epoch 13/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9829 - loss: 0.1552
# Epoch 13: val_accuracy improved from 0.96656 to 0.96767, saving model to ensemble_model_MobileNet.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 37s 232ms/step - accuracy: 0.9829 - loss: 0.1552 - val_accuracy: 0.9677 - val_loss: 0.1408 - learning_rate: 1.0000e-04
# Epoch 14/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9862 - loss: 0.1259
# Epoch 14: val_accuracy did not improve from 0.96767
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 140ms/step - accuracy: 0.9862 - loss: 0.1259 - val_accuracy: 0.9666 - val_loss: 0.1240 - learning_rate: 1.0000e-05
# Epoch 15/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9880 - loss: 0.1231
# Epoch 15: val_accuracy improved from 0.96767 to 0.96878, saving model to ensemble_model_MobileNet.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 37s 235ms/step - accuracy: 0.9880 - loss: 0.1231 - val_accuracy: 0.9688 - val_loss: 0.1215 - learning_rate: 1.0000e-05
# Epoch 16/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9888 - loss: 0.1097
# Epoch 16: val_accuracy did not improve from 0.96878
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9888 - loss: 0.1098 - val_accuracy: 0.9677 - val_loss: 0.1201 - learning_rate: 1.0000e-05
# Epoch 17/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9837 - loss: 0.1258
# Epoch 17: val_accuracy did not improve from 0.96878
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9837 - loss: 0.1258 - val_accuracy: 0.9688 - val_loss: 0.1191 - learning_rate: 1.0000e-05
# Epoch 18/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9894 - loss: 0.1175
# Epoch 18: val_accuracy improved from 0.96878 to 0.97101, saving model to ensemble_model_MobileNet.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 38s 240ms/step - accuracy: 0.9894 - loss: 0.1175 - val_accuracy: 0.9710 - val_loss: 0.1208 - learning_rate: 1.0000e-05
# Epoch 19/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9851 - loss: 0.1124
# Epoch 19: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9852 - loss: 0.1124 - val_accuracy: 0.9688 - val_loss: 0.1190 - learning_rate: 1.0000e-05
# Epoch 20/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9875 - loss: 0.1147
# Epoch 20: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9875 - loss: 0.1147 - val_accuracy: 0.9688 - val_loss: 0.1183 - learning_rate: 1.0000e-05
# Epoch 21/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9926 - loss: 0.0957
# Epoch 21: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9926 - loss: 0.0958 - val_accuracy: 0.9688 - val_loss: 0.1170 - learning_rate: 1.0000e-05
# Epoch 22/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9837 - loss: 0.1179
# Epoch 22: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9837 - loss: 0.1179 - val_accuracy: 0.9688 - val_loss: 0.1159 - learning_rate: 1.0000e-05
# Epoch 23/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9866 - loss: 0.1189
# Epoch 23: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9866 - loss: 0.1188 - val_accuracy: 0.9688 - val_loss: 0.1166 - learning_rate: 1.0000e-05
# Epoch 24/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9881 - loss: 0.1176
# Epoch 24: val_accuracy did not improve from 0.97101
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9881 - loss: 0.1176 - val_accuracy: 0.9688 - val_loss: 0.1172 - learning_rate: 1.0000e-05
# Epoch 25/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9868 - loss: 0.1112
# Epoch 25: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9868 - loss: 0.1112 - val_accuracy: 0.9688 - val_loss: 0.1165 - learning_rate: 1.0000e-06
# Epoch 26/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9892 - loss: 0.1013
# Epoch 26: val_accuracy did not improve from 0.97101
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9892 - loss: 0.1013 - val_accuracy: 0.9688 - val_loss: 0.1161 - learning_rate: 1.0000e-06
# Epoch 27/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9910 - loss: 0.1029
# Epoch 27: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9910 - loss: 0.1029 - val_accuracy: 0.9688 - val_loss: 0.1157 - learning_rate: 1.0000e-07
# Epoch 28/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9881 - loss: 0.1066
# Epoch 28: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9881 - loss: 0.1066 - val_accuracy: 0.9688 - val_loss: 0.1155 - learning_rate: 1.0000e-07
# Epoch 29/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9881 - loss: 0.1052
# Epoch 29: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9881 - loss: 0.1052 - val_accuracy: 0.9688 - val_loss: 0.1155 - learning_rate: 1.0000e-07
# Epoch 30/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9889 - loss: 0.1155
# Epoch 30: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9889 - loss: 0.1155 - val_accuracy: 0.9688 - val_loss: 0.1151 - learning_rate: 1.0000e-07
# Epoch 31/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9893 - loss: 0.1001
# Epoch 31: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9893 - loss: 0.1001 - val_accuracy: 0.9688 - val_loss: 0.1151 - learning_rate: 1.0000e-07
# Epoch 32/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9886 - loss: 0.0981
# Epoch 32: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 138ms/step - accuracy: 0.9885 - loss: 0.0981 - val_accuracy: 0.9699 - val_loss: 0.1148 - learning_rate: 1.0000e-07
# Epoch 33/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9888 - loss: 0.1040
# Epoch 33: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 138ms/step - accuracy: 0.9888 - loss: 0.1040 - val_accuracy: 0.9699 - val_loss: 0.1146 - learning_rate: 1.0000e-07
# Epoch 34/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9875 - loss: 0.1066
# Epoch 34: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 138ms/step - accuracy: 0.9875 - loss: 0.1066 - val_accuracy: 0.9699 - val_loss: 0.1146 - learning_rate: 1.0000e-07
# Epoch 35/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9893 - loss: 0.1005
# Epoch 35: val_accuracy did not improve from 0.97101
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-07.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9893 - loss: 0.1005 - val_accuracy: 0.9688 - val_loss: 0.1146 - learning_rate: 1.0000e-07
# Epoch 36/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9884 - loss: 0.1072
# Epoch 36: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9884 - loss: 0.1072 - val_accuracy: 0.9688 - val_loss: 0.1146 - learning_rate: 1.0000e-07
# Epoch 37/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9891 - loss: 0.1039
# Epoch 37: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 140ms/step - accuracy: 0.9891 - loss: 0.1039 - val_accuracy: 0.9688 - val_loss: 0.1145 - learning_rate: 1.0000e-07
# Epoch 38/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9896 - loss: 0.1065
# Epoch 38: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9896 - loss: 0.1065 - val_accuracy: 0.9688 - val_loss: 0.1145 - learning_rate: 1.0000e-07
# Epoch 39/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9901 - loss: 0.0990
# Epoch 39: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9901 - loss: 0.0991 - val_accuracy: 0.9688 - val_loss: 0.1141 - learning_rate: 1.0000e-07
# Epoch 40/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9898 - loss: 0.1039
# Epoch 40: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9898 - loss: 0.1039 - val_accuracy: 0.9688 - val_loss: 0.1142 - learning_rate: 1.0000e-07
# Epoch 41/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9909 - loss: 0.0948
# Epoch 41: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9908 - loss: 0.0948 - val_accuracy: 0.9688 - val_loss: 0.1142 - learning_rate: 1.0000e-07
# Epoch 42/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9901 - loss: 0.1031
# Epoch 42: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9901 - loss: 0.1032 - val_accuracy: 0.9688 - val_loss: 0.1140 - learning_rate: 1.0000e-07
# Epoch 43/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9891 - loss: 0.1019
# Epoch 43: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9891 - loss: 0.1019 - val_accuracy: 0.9688 - val_loss: 0.1139 - learning_rate: 1.0000e-07
# Epoch 44/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9864 - loss: 0.1072
# Epoch 44: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9864 - loss: 0.1072 - val_accuracy: 0.9699 - val_loss: 0.1134 - learning_rate: 1.0000e-07
# Epoch 45/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9904 - loss: 0.1041
# Epoch 45: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9904 - loss: 0.1041 - val_accuracy: 0.9688 - val_loss: 0.1136 - learning_rate: 1.0000e-07
# Epoch 46/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9898 - loss: 0.1061
# Epoch 46: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9898 - loss: 0.1061 - val_accuracy: 0.9699 - val_loss: 0.1135 - learning_rate: 1.0000e-07
# Epoch 47/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9898 - loss: 0.1004
# Epoch 47: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9898 - loss: 0.1004 - val_accuracy: 0.9699 - val_loss: 0.1133 - learning_rate: 1.0000e-07
# Epoch 48/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9900 - loss: 0.0979
# Epoch 48: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9900 - loss: 0.0979 - val_accuracy: 0.9699 - val_loss: 0.1132 - learning_rate: 1.0000e-07
# Epoch 49/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9907 - loss: 0.1020
# Epoch 49: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9907 - loss: 0.1020 - val_accuracy: 0.9699 - val_loss: 0.1132 - learning_rate: 1.0000e-07
# Epoch 50/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9884 - loss: 0.1081
# Epoch 50: val_accuracy did not improve from 0.97101
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 139ms/step - accuracy: 0.9884 - loss: 0.1080 - val_accuracy: 0.9699 - val_loss: 0.1128 - learning_rate: 1.0000e-07
# Restoring model weights from the end of the best epoch: 50.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 12s 359ms/step - accuracy: 0.9609 - loss: 0.1577
# Test Accuracy: 0.9677724838256836

# %%
# Plotting training and validation loss
plt.figure(figsize=(12, 5),facecolor="black")

plt.subplot(1, 2, 1,facecolor='black')
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
mplcyberpunk.make_lines_glow()

# Plotting training and validation accuracy
plt.subplot(1, 2, 2,facecolor='black')
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
mplcyberpunk.make_lines_glow()

plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure `labels` is defined with your class names, e.g., labels = ['Class 0', 'Class 1', 'Class 2', 'Class 3']
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# Calculate true and predicted labels
y_true_test = np.argmax(y_test, axis=1)
y_pred_test = np.argmax(ensemble_model.predict([X_test, X_test]), axis=1)  # Use ensemble_model here

# Plot confusion matrix
heatmap = sns.heatmap(confusion_matrix(y_true_test, y_pred_test), annot=True, fmt='d', cmap='Blues_r',
                      xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step

# %%
print(classification_report(y_true_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       259
#            1       0.99      0.98      0.98       298
#            2       0.93      0.94      0.93       237
#            3       0.98      0.98      0.98       261
#
#     accuracy                           0.97      1055
#    macro avg       0.97      0.97      0.97      1055
# weighted avg       0.97      0.97      0.97      1055

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define your class labels
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# Select a random image from the test set
random_index = np.random.randint(0, len(X_test))
random_img = X_test[random_index]

# Make a prediction using ensemble_model
predictions = ensemble_model.predict([random_img.reshape(1, 340, 340, 3), random_img.reshape(1, 340, 340, 3)])  # Reshape for both input branches

# Interpret the model's predictions
predicted_class = np.argmax(predictions)  # Get the index of the class with the highest probability
predicted_label = labels[predicted_class]  # Convert class index to label
confidence = predictions[0][predicted_class]  # Get the confidence score

# Get the actual class label
actual_index = y_test[random_index]  # Get the one-hot encoded actual class
actual_class = np.argmax(actual_index)
actual_label = labels[actual_class]

# Display the image and prediction information
print(f"\033[94mPredicted label: {predicted_label}\033[0m")
print(f"\033[92mActual label: {actual_label}\033[0m")
print(f"\033[95mConfidence: {confidence*100:.2f}%\033[0m\n")

# Show the image
plt.figure(figsize=(3, 3))
plt.imshow(random_img)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted label: meningioma_tumor
# Actual label: meningioma_tumor
# Confidence: 99.90%

# %%
# Evaluate the model with duplicated inputs for testing
test_loss, test_accuracy = ensemble_model.evaluate([X_test, X_test], y_test, verbose=1)  # Provide both inputs
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9609 - loss: 0.1577
# Test Accuracy: 96.78%
